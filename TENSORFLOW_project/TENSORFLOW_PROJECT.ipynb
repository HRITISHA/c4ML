# %%
import tensorflow as tf
import keras

import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
data= tf.keras.datasets.mnist

# %%
(train_xdig, train_ydig), (test_xdig, test_ydig) = data.load_data()

# %%
train_ydig
train_xdig.shape
# Out:
# (60000, 28, 28)

# %%
train_ydig
train_ydig.shape
# Out:
# (60000,)

# %%
test_xdig
test_xdig.shape
# Out:
# (10000, 28, 28)

# %%
test_ydig
test_ydig.shape
# Out:
# (10000,)

# %%
plt.figure()
plt.imshow(train_xdig[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure()
plt.imshow(train_xdig[2])
plt.colorbar()
plt.grid()
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(15,15))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid()
    plt.imshow(train_xdig[i], cmap='magma')
plt.show()

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
model.fit(x=train_xdig,y=train_ydig, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 5s 85us/step - loss: 1.6880 - accuracy: 0.7358
# Epoch 2/10
# 60000/60000 [==============================] - 5s 78us/step - loss: 1.9096 - accuracy: 0.6880
# Epoch 3/10
# 60000/60000 [==============================] - 4s 72us/step - loss: 2.0165 - accuracy: 0.6349
# Epoch 4/10
# 60000/60000 [==============================] - 4s 74us/step - loss: 2.0169 - accuracy: 0.5556
# Epoch 5/10
# 60000/60000 [==============================] - 5s 77us/step - loss: 2.1214 - accuracy: 0.5173
# Epoch 6/10
# 60000/60000 [==============================] - 5s 90us/step - loss: 2.2124 - accuracy: 0.5095
# Epoch 7/10
# 60000/60000 [==============================] - 6s 94us/step - loss: 2.2143 - accuracy: 0.4388
# Epoch 8/10
# 60000/60000 [==============================] - 6s 92us/step - loss: 2.2005 - accuracy: 0.4063
# Epoch 9/10
# 60000/60000 [==============================] - 5s 89us/step - loss: 2.1900 - accuracy: 0.4126
# Epoch 10/10
# ...

# %%
model.evaluate(test_xdig, test_ydig)
# Out:
# 10000/10000 [==============================] - 0s 28us/step
# [2.1791667915344237, 0.421099990606308]

# %%
img_rows, img_cols = 28, 28
image_index = 4744
plt.imshow(test_xdig[image_index].reshape(28, 28),cmap='Greys')
pred = model.predict(test_xdig[image_index].reshape(1,784, 1))
print(pred.argmax())
# Out:
# 154
